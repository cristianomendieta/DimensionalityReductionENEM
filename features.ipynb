# %%
# !pip install pandas

import pandas as pd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 3.8 MB/s eta 0:00:00
# ...
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 46.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 42.3 MB/s eta 0:00:0000:0100:01
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# ...
#
# [notice] A new release of pip is available: 24.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
df = pd.read_csv('/home/cristiano/ufpr/tcc/MICRODADOS_ENEM_2022.csv', sep=';', encoding='ISO-8859-1')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
descartar = [
    'NU_INSCRICAO', 
    'NU_ANO', 
    'TX_RESPOSTAS_CN', 
    'TX_RESPOSTAS_CH', 
    'TX_RESPOSTAS_LC',
    'TX_RESPOSTAS_MT',
    'TX_GABARITO_CN', 
    'TX_GABARITO_CH',
    'TX_GABARITO_LC', 
    'TX_GABARITO_MT', 
    'TP_ENSINO',              
    'CO_MUNICIPIO_ESC',       
    'NO_MUNICIPIO_ESC',       
    'CO_UF_ESC',              
    'SG_UF_ESC',              
    'TP_DEPENDENCIA_ADM_ESC', 
    'TP_LOCALIZACAO_ESC',     
    'TP_SIT_FUNC_ESC',        
    'CO_PROVA_CN',            
    'CO_PROVA_CH',            
    'CO_PROVA_LC',            
    'CO_PROVA_MT'
]

# %%
new_df = df[descartar]
# Out:
#          NU_INSCRICAO  NU_ANO                                TX_RESPOSTAS_CN  \
# 0        210057943671    2022                                            NaN
# 1        210057516120    2022                                            NaN
# 2        210057280536    2022  DCDCEBADDABEDBCBEAEACCDDECEEBECBECAAECDDDDBCE
# 3        210055724397    2022  BACBBABBCAABCABBCBACBCBCBACABACABCBDBCBABAACA
# 4        210055097896    2022                                            NaN
# ...               ...     ...                                            ...
# 2359791  210057381361    2022  ABCDEDCECADDEAEADBBCECDBACEEABEDCBBBBDACEDACA
# 2359792  210055778839    2022  AECBDEDAACDACEBABCDDABBEDBCCEBBAABDCDBECCDACA
# 2359793  210054996030    2022                                            NaN
# 2359794  210056203274    2022  AEDCAADCBCECBBEAADCCABECAACEDEBCEAAEDADBCBBBC
# 2359795  210054755820    2022                                            NaN
#
# ...

# %%
new_df.to_csv('./colunas_descartadas.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 new_df.to_csv('./colunas_descartadas.csv', index=False)
#
# NameError: name 'new_df' is not defined

# %%
df.shape
# Out:
# (2359796, 76)
